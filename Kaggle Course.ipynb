# %%
import pandas as pd

# %% [markdown]
# The mos important part of `Pandas` is the DataFrame
#
# **DataFrame:** Holds the data as tables, like a table in SQL.

# %%
# file path location
melbourne_file_path = 'input/CSV/melb_data.csv'
# store the data in a DataFrame named melbourne_data
melbourne_data = pd.read_csv(melbourne_file_path)
melbourne_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %% [markdown]
# ### Picking some  variables

# %%
import pandas as pd

# file path location
melbourne_file_path = 'input/CSV/melb_data.csv'
# store the data in a DataFrame named melbourne_data
melbourne_data = pd.read_csv(melbourne_file_path)
melbourne_data.columns
melbourne_data
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %% [markdown]
# Drops the lines where there is missing values

# %%
melbourne_data.dropna(axis=0)
# Out:
#              Suburb          Address  Rooms Type      Price Method  \
# 1        Abbotsford  25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford     5 Charles St      3    h  1465000.0     SP
# 4        Abbotsford      55a Park St      4    h  1600000.0     VB
# 6        Abbotsford     124 Yarra St      3    h  1876000.0      S
# 7        Abbotsford    98 Charles St      2    h  1636000.0      S
# ...             ...              ...    ...  ...        ...    ...
# 12205    Whittlesea    30 Sherwin St      3    h   601000.0      S
# 12206  Williamstown      75 Cecil St      3    h  1050000.0     VB
# 12207  Williamstown    2/29 Dover Rd      1    u   385000.0     SP
# 12209       Windsor  201/152 Peel St      2    u   560000.0     PI
# 12212    Yarraville  54 Pentland Pde      6    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# ...

# %% [markdown]
# ### Choose a target
# Dot-notation: choose the column you want to predict. This column is the target, by convention stored in y.

# %%
y = melbourne_data.Price

# %% [markdown]
# ### Chose the features
# Those columns that will be used as input to the modle (and latter used to predict the target) are called features.
#
# In this case, the columns used to predict the **price** are the targets.
#
# **We select multiple features by providing a list of column names inside brackets.**

# %%
melbourne_features = ["Rooms", "Bathroom", "Landsize", "Lattitude", "Longtitude"]

# %% [markdown]
# By convention this data is called X:

# %%
X = melbourne_data[melbourne_features]
X.describe()
# Out:
#               Rooms      Bathroom       Landsize     Lattitude    Longtitude
# count  13580.000000  13580.000000   13580.000000  13580.000000  13580.000000
# mean       2.937997      1.534242     558.416127    -37.809203    144.995216
# std        0.955748      0.691712    3990.669241      0.079260      0.103916
# min        1.000000      0.000000       0.000000    -38.182550    144.431810
# 25%        2.000000      1.000000     177.000000    -37.856822    144.929600
# 50%        3.000000      1.000000     440.000000    -37.802355    145.000100
# 75%        3.000000      2.000000     651.000000    -37.756400    145.058305
# max       10.000000      8.000000  433014.000000    -37.408530    145.526350

# %% [markdown]
# ## Buiild a Model
#
# The steps to building and using a model are:
#
# - Define: What type of model will it be? A decision tree? Some other type of model? Some other parameters of the model type are specified too.
# - Fit: Capture patterns from provided data. This is the heart of modeling.
# - Predict: Just what it sounds like
# - Evaluate: Determine how accurate the model's predictions are.

# %%
from sklearn.tree import DecisionTreeRegressor

# Define a model (random_state=1 ensures same results every run)
melbourne_model = DecisionTreeRegressor(random_state=1)

# Train the model
melbourne_model.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=1, splitter='best')

# %% [markdown]
# ## Predicting

# %%
print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(melbourne_model.predict(X.head()))
# Out:
# Making predictions for the following 5 houses:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 0      2       1.0     202.0   -37.7996    144.9984
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 3      3       2.0      94.0   -37.7969    144.9969
# 4      4       1.0     120.0   -37.8072    144.9941
# The predictions are
# [1480000. 1035000. 1465000.  850000. 1600000.]

# %%
melbourne_predicted = melbourne_model.predict(X)

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# **Mean absolute error:** `error=absolute-predicted`. Make this for all the data and take the mean.

# %%
mean_absolute_error(y, melbourne_predicted)
# Out:
# 1125.1804614629357

# %% [markdown]
# ## Split

# %%
from sklearn.model_selection import train_test_split

# split data into training and validation data, for both features and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we
# run this script.
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# Define model
melbourne_model = DecisionTreeRegressor()
# Fit model
melbourne_model.fit(train_X, train_y)

# get predicted prices on validation data
val_predictions = melbourne_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 247054.0978890525

# %% [markdown]
# ## Underfitting and Overfitting

# %% [markdown]
# #### Overfitting
# The data is divided amongst many leaves then, each leaf contains very few houses, so the predictions are based in a few houses. The model matches very well for the **training data** but very poorly for **new data**.
#
# #### Underfitting
# In the other hand, if the tree gets splitted just a few times, the leaves will have groups with a wide variety of houses. The predictions based in those groups may be far off even for the training data.

# %% [markdown]
# So whats we are looking for is a **spot between overfitting and underfitting**.
# ![](http://i.imgur.com/2q85n9s.png)

# %% [markdown]
# In order to controll the tree depth we can use the argument `max_leaf_nodes`.

# %%
# Utility function to compare differents values to max_leaf_nodes

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    predictions = model.predict(val_X)
    mae = mean_absolute_error(val_y, predictions)
    return mae

# %%
import pandas as pd

melbourne_file_path = 'input/CSV/melb_data.csv'
melbourne_data = pd.read_csv(melbourne_file_path)

y = melbourne_data.Price

melbourne_features = ["Rooms", "Bathroom", "Landsize", "Lattitude", "Longtitude"]

X = melbourne_data[melbourne_features]

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

train_X, val_X, train_y, val_y = train_test_split(X, y)
mae_axis = []
leaves_axis = []


for max_leaf_nodes in range(10, 4000, 20):
    mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    mae_axis.append(mae)
    leaves_axis.append(max_leaf_nodes)
    

plt.plot(leaves_axis, mae_axis)
plt.xlabel("Number of leaves")
plt.ylabel("Mean absolute error")
# Out:
# Text(0,0.5,'Mean absolute error')

# %% [markdown]
# ## Random Forests

# %% [markdown]
# When working with decision trees, one must be careful with the `max_leaf_nodes` because of the overfitting X underfitting issue. A deep tree will overfit and a shallow tree will give poor predictions.
#
# To solve this tension between overfitting and underfitting we will use **Random Forests**. A random forest takes many trees and it make predictions by taking the average prediction of each component tree.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)
melb_predictions = forest_model.predict(val_X)
mae = mean_absolute_error(val_y, melb_predictions)
print(mae)
# Out:
# /home/jean/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 191005.21887509644
