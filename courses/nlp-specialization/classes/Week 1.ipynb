# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ![3vVQr0zhTlW1UK9M4V5Vww_e5b656e0d36041e1be5edd54bd3562a5_Screen-Shot-2020-09-01-at-7.35.25-AM.png](attachment:3vVQr0zhTlW1UK9M4V5Vww_e5b656e0d36041e1be5edd54bd3562a5_Screen-Shot-2020-09-01-at-7.35.25-AM.png)

# %% [markdown]
# ![z84yBRbCS0qOMgUWwktKdA_927d67ce246c4212ad9d389a0243ed0e_Screen-Shot-2020-09-01-at-7.41.26-AM.png](attachment:z84yBRbCS0qOMgUWwktKdA_927d67ce246c4212ad9d389a0243ed0e_Screen-Shot-2020-09-01-at-7.41.26-AM.png)

# %% [markdown]
# ## Vocabulary & Feature Extraction

# %% [markdown]
# ![vpVZPKHCS6uVWTyhwmurrQ_d2e2fd874a354ab38047ef531021b681_Screen-Shot-2020-09-01-at-7.48.25-AM.png](attachment:vpVZPKHCS6uVWTyhwmurrQ_d2e2fd874a354ab38047ef531021b681_Screen-Shot-2020-09-01-at-7.48.25-AM.png)

# %% [markdown]
# ## Feature Extraction with Frequencies

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Putting it all together

# %% [markdown]
# Given a raw string (e.g. extracted from tweet), the first step is to preprocess it and extract the features.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# With the features, with all tweets, we assemble a matrix X.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Logistic Regression: Training

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Logistic Regression: Testing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Logistic Regression: Loss

# %% [markdown]
# ![image.png](attachment:image.png)
